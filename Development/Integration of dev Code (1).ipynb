# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import cv2
import numpy as np
import os

class VideoProcessor:
    def __init__(self, video_path, output_folder):
        self.video_path = video_path
        self.output_folder = output_folder
        
        # Ensure the output directory exists
        os.makedirs(output_folder, exist_ok=True)
        
    def process_video(self):
        # Capture the video
        video_cap = cv2.VideoCapture(self.video_path)
        
        if not video_cap.isOpened():
            raise ValueError("Error opening video file")
        
        # Get video properties
        fps = int(video_cap.get(cv2.CAP_PROP_FPS))  # Frames per second
        total_frames = int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT))  # Total number of frames
        duration = int(total_frames / fps)  # Duration of the video in seconds
        
        print(f"FPS: {fps}, Total Frames: {total_frames}, Duration: {duration} seconds")

        all_frames_per_second = []  # List to hold lists of frames for each second
        frame_list = []  # Temporary list to hold frames for one second
        frame_count = 0  # Counter to track frames in a second

        while video_cap.isOpened():
            ret, frame = video_cap.read()
            
            if not ret:
                break
            
            frame_list.append(frame)  # Add the current frame to the current second's list
            frame_count += 1
            
            # Once we've collected 'fps' frames (i.e., 1 second worth of frames)
            if frame_count == fps:
                all_frames_per_second.append(frame_list)  # Save this second's frames
                self._save_frames(frame_list, len(all_frames_per_second) - 1)  # Save frames to disk
                frame_list = []  # Reset for the next second
                frame_count = 0

        # Handling the last set of frames (if video doesn't perfectly divide into seconds)
        if frame_list:
            all_frames_per_second.append(frame_list)
            self._save_frames(frame_list, len(all_frames_per_second) - 1)

        video_cap.release()
        return all_frames_per_second
    
    def _save_frames(self, frame_list, current_sec):
        
        for idx, frame in enumerate(frame_list):
            filename = f"{self.output_folder}/{current_sec},{idx}.npy"
            np.save(filename, frame)
            print(f"Saved frame {idx} of second {current_sec} to {filename}")

# %%
n1 = VideoProcessor('src/vid1.mp4', 'output2').process_video()
# Out:
# FPS: 25, Total Frames: 1149, Duration: 45 seconds
# Saved frame 0 of second 0 to output2/0,0.npy
# Saved frame 1 of second 0 to output2/0,1.npy
# Saved frame 2 of second 0 to output2/0,2.npy
# Saved frame 3 of second 0 to output2/0,3.npy
# Saved frame 4 of second 0 to output2/0,4.npy
# Saved frame 5 of second 0 to output2/0,5.npy
# Saved frame 6 of second 0 to output2/0,6.npy
# Saved frame 7 of second 0 to output2/0,7.npy
# Saved frame 8 of second 0 to output2/0,8.npy
# Saved frame 9 of second 0 to output2/0,9.npy
# Saved frame 10 of second 0 to output2/0,10.npy
# Saved frame 11 of second 0 to output2/0,11.npy
# Saved frame 12 of second 0 to output2/0,12.npy
# Saved frame 13 of second 0 to output2/0,13.npy
# Saved frame 14 of second 0 to output2/0,14.npy
# Saved frame 15 of second 0 to output2/0,15.npy
# Saved frame 16 of second 0 to output2/0,16.npy
# Saved frame 17 of second 0 to output2/0,17.npy
# Saved frame 18 of second 0 to output2/0,18.npy
# Saved frame 19 of second 0 to output2/0,19.npy
# Saved frame 20 of second 0 to output2/0,20.npy
# Saved frame 21 of second 0 to output2/0,21.npy
# Saved frame 22 of second 0 to output2/0,22.npy
# Saved frame 23 of second 0 to output2/0,23.npy
# Saved frame 24 of second 0 to output2/0,24.npy
# Saved frame 0 of second 1 to output2/1,0.npy
# Saved frame 1 of second 1 to output2/1,1.npy
# Saved frame 2 of second 1 to output2/1,2.npy
# Saved frame 3 of second 1 to output2/1,3.npy
# Saved frame 4 of second 1 to output2/1,4.npy
# Saved frame 5 of second 1 to output2/1,5.npy
# Saved frame 6 of second 1 to output2/1,6.npy
# Saved frame 7 of second 1 to output2/1,7.npy
# Saved frame 8 of second 1 to output2/1,8.npy
# Saved frame 9 of second 1 to output2/1,9.npy
# Saved frame 10 of second 1 to output2/1,10.npy
# Saved frame 11 of second 1 to output2/1,11.npy
# Saved frame 12 of second 1 to output2/1,12.npy
# Saved frame 13 of second 1 to output2/1,13.npy
# Saved frame 14 of second 1 to output2/1,14.npy
# Saved frame 15 of second 1 to output2/1,15.npy
# Saved frame 16 of second 1 to output2/1,16.npy
# Saved frame 17 of second 1 to output2/1,17.npy
# Saved frame 18 of second 1 to output2/1,18.npy
# Saved frame 19 of second 1 to output2/1,19.npy
# Saved frame 20 of second 1 to output2/1,20.npy
# Saved frame 21 of second 1 to output2/1,21.npy
# Saved frame 22 of second 1 to output2/1,22.npy
# Saved frame 23 of second 1 to output2/1,23.npy
# Saved frame 24 of second 1 to output2/1,24.npy
# Saved frame 0 of second 2 to output2/2,0.npy
# Saved frame 1 of second 2 to output2/2,1.npy
# Saved frame 2 of second 2 to output2/2,2.npy
# Saved frame 3 of second 2 to output2/2,3.npy
# Saved frame 4 of second 2 to output2/2,4.npy
# Saved frame 5 of second 2 to output2/2,5.npy
# Saved frame 6 of second 2 to output2/2,6.npy
# Saved frame 7 of second 2 to output2/2,7.npy
# Saved frame 8 of second 2 to output2/2,8.npy
# Saved frame 9 of second 2 to output2/2,9.npy
# Saved frame 10 of second 2 to output2/2,10.npy
# Saved frame 11 of second 2 to output2/2,11.npy
# Saved frame 12 of second 2 to output2/2,12.npy
# Saved frame 13 of second 2 to output2/2,13.npy
# Saved frame 14 of second 2 to output2/2,14.npy
# Saved frame 15 of second 2 to output2/2,15.npy
# Saved frame 16 of second 2 to output2/2,16.npy
# Saved frame 17 of second 2 to output2/2,17.npy
# Saved frame 18 of second 2 to output2/2,18.npy
# Saved frame 19 of second 2 to output2/2,19.npy
# Saved frame 20 of second 2 to output2/2,20.npy
# Saved frame 21 of second 2 to output2/2,21.npy
# Saved frame 22 of second 2 to output2/2,22.npy
# Saved frame 23 of second 2 to output2/2,23.npy
# Saved frame 24 of second 2 to output2/2,24.npy
# Saved frame 0 of second 3 to output2/3,0.npy
# Saved frame 1 of second 3 to output2/3,1.npy
# Saved frame 2 of second 3 to output2/3,2.npy
# Saved frame 3 of second 3 to output2/3,3.npy
# Saved frame 4 of second 3 to output2/3,4.npy
# Saved frame 5 of second 3 to output2/3,5.npy
# Saved frame 6 of second 3 to output2/3,6.npy
# Saved frame 7 of second 3 to output2/3,7.npy
# Saved frame 8 of second 3 to output2/3,8.npy
# Saved frame 9 of second 3 to output2/3,9.npy
# Saved frame 10 of second 3 to output2/3,10.npy
# Saved frame 11 of second 3 to output2/3,11.npy
# Saved frame 12 of second 3 to output2/3,12.npy
# Saved frame 13 of second 3 to output2/3,13.npy
# Saved frame 14 of second 3 to output2/3,14.npy
# Saved frame 15 of second 3 to output2/3,15.npy
# Saved frame 16 of second 3 to output2/3,16.npy
# Saved frame 17 of second 3 to output2/3,17.npy
# Saved frame 18 of second 3 to output2/3,18.npy
# Saved frame 19 of second 3 to output2/3,19.npy
# Saved frame 20 of second 3 to output2/3,20.npy
# Saved frame 21 of second 3 to output2/3,21.npy
# Saved frame 22 of second 3 to output2/3,22.npy
# Saved frame 23 of second 3 to output2/3,23.npy
# Saved frame 24 of second 3 to output2/3,24.npy
# Saved frame 0 of second 4 to output2/4,0.npy
# Saved frame 1 of second 4 to output2/4,1.npy
# Saved frame 2 of second 4 to output2/4,2.npy
# Saved frame 3 of second 4 to output2/4,3.npy
# Saved frame 4 of second 4 to output2/4,4.npy
# Saved frame 5 of second 4 to output2/4,5.npy
# Saved frame 6 of second 4 to output2/4,6.npy
# Saved frame 7 of second 4 to output2/4,7.npy
# Saved frame 8 of second 4 to output2/4,8.npy
# Saved frame 9 of second 4 to output2/4,9.npy
# Saved frame 10 of second 4 to output2/4,10.npy
# Saved frame 11 of second 4 to output2/4,11.npy
# Saved frame 12 of second 4 to output2/4,12.npy
# Saved frame 13 of second 4 to output2/4,13.npy
# Saved frame 14 of second 4 to output2/4,14.npy
# Saved frame 15 of second 4 to output2/4,15.npy
# Saved frame 16 of second 4 to output2/4,16.npy
# Saved frame 17 of second 4 to output2/4,17.npy
# Saved frame 18 of second 4 to output2/4,18.npy
# Saved frame 19 of second 4 to output2/4,19.npy
# Saved frame 20 of second 4 to output2/4,20.npy
# Saved frame 21 of second 4 to output2/4,21.npy
# Saved frame 22 of second 4 to output2/4,22.npy
# Saved frame 23 of second 4 to output2/4,23.npy
# Saved frame 24 of second 4 to output2/4,24.npy
# Saved frame 0 of second 5 to output2/5,0.npy
# Saved frame 1 of second 5 to output2/5,1.npy
# Saved frame 2 of second 5 to output2/5,2.npy
# Saved frame 3 of second 5 to output2/5,3.npy
# Saved frame 4 of second 5 to output2/5,4.npy
# Saved frame 5 of second 5 to output2/5,5.npy
# Saved frame 6 of second 5 to output2/5,6.npy
# Saved frame 7 of second 5 to output2/5,7.npy
# Saved frame 8 of second 5 to output2/5,8.npy
# Saved frame 9 of second 5 to output2/5,9.npy
# Saved frame 10 of second 5 to output2/5,10.npy
# Saved frame 11 of second 5 to output2/5,11.npy
# Saved frame 12 of second 5 to output2/5,12.npy
# Saved frame 13 of second 5 to output2/5,13.npy
# Saved frame 14 of second 5 to output2/5,14.npy
# Saved frame 15 of second 5 to output2/5,15.npy
# Saved frame 16 of second 5 to output2/5,16.npy
# Saved frame 17 of second 5 to output2/5,17.npy
# Saved frame 18 of second 5 to output2/5,18.npy
# Saved frame 19 of second 5 to output2/5,19.npy
# Saved frame 20 of second 5 to output2/5,20.npy
# Saved frame 21 of second 5 to output2/5,21.npy
# Saved frame 22 of second 5 to output2/5,22.npy
# Saved frame 23 of second 5 to output2/5,23.npy
# Saved frame 24 of second 5 to output2/5,24.npy
# Saved frame 0 of second 6 to output2/6,0.npy
# Saved frame 1 of second 6 to output2/6,1.npy
# Saved frame 2 of second 6 to output2/6,2.npy
# Saved frame 3 of second 6 to output2/6,3.npy
# Saved frame 4 of second 6 to output2/6,4.npy
# Saved frame 5 of second 6 to output2/6,5.npy
# Saved frame 6 of second 6 to output2/6,6.npy
# Saved frame 7 of second 6 to output2/6,7.npy
# Saved frame 8 of second 6 to output2/6,8.npy
# Saved frame 9 of second 6 to output2/6,9.npy
# Saved frame 10 of second 6 to output2/6,10.npy
# Saved frame 11 of second 6 to output2/6,11.npy
# Saved frame 12 of second 6 to output2/6,12.npy
# Saved frame 13 of second 6 to output2/6,13.npy
# Saved frame 14 of second 6 to output2/6,14.npy
# Saved frame 15 of second 6 to output2/6,15.npy
# Saved frame 16 of second 6 to output2/6,16.npy
# Saved frame 17 of second 6 to output2/6,17.npy
# Saved frame 18 of second 6 to output2/6,18.npy
# Saved frame 19 of second 6 to output2/6,19.npy
# Saved frame 20 of second 6 to output2/6,20.npy
# Saved frame 21 of second 6 to output2/6,21.npy
# Saved frame 22 of second 6 to output2/6,22.npy
# Saved frame 23 of second 6 to output2/6,23.npy
# Saved frame 24 of second 6 to output2/6,24.npy
# Saved frame 0 of second 7 to output2/7,0.npy
# Saved frame 1 of second 7 to output2/7,1.npy
# Saved frame 2 of second 7 to output2/7,2.npy
# Saved frame 3 of second 7 to output2/7,3.npy
# Saved frame 4 of second 7 to output2/7,4.npy
# Saved frame 5 of second 7 to output2/7,5.npy
# Saved frame 6 of second 7 to output2/7,6.npy
# Saved frame 7 of second 7 to output2/7,7.npy
# Saved frame 8 of second 7 to output2/7,8.npy
# Saved frame 9 of second 7 to output2/7,9.npy
# Saved frame 10 of second 7 to output2/7,10.npy
# Saved frame 11 of second 7 to output2/7,11.npy
# Saved frame 12 of second 7 to output2/7,12.npy
# Saved frame 13 of second 7 to output2/7,13.npy
# Saved frame 14 of second 7 to output2/7,14.npy
# Saved frame 15 of second 7 to output2/7,15.npy
# Saved frame 16 of second 7 to output2/7,16.npy
# Saved frame 17 of second 7 to output2/7,17.npy
# Saved frame 18 of second 7 to output2/7,18.npy
# Saved frame 19 of second 7 to output2/7,19.npy
# Saved frame 20 of second 7 to output2/7,20.npy
# Saved frame 21 of second 7 to output2/7,21.npy
# Saved frame 22 of second 7 to output2/7,22.npy
# Saved frame 23 of second 7 to output2/7,23.npy
# Saved frame 24 of second 7 to output2/7,24.npy
# Saved frame 0 of second 8 to output2/8,0.npy
# Saved frame 1 of second 8 to output2/8,1.npy
# Saved frame 2 of second 8 to output2/8,2.npy
# Saved frame 3 of second 8 to output2/8,3.npy
# Saved frame 4 of second 8 to output2/8,4.npy
# Saved frame 5 of second 8 to output2/8,5.npy
# Saved frame 6 of second 8 to output2/8,6.npy
# Saved frame 7 of second 8 to output2/8,7.npy
# Saved frame 8 of second 8 to output2/8,8.npy
# Saved frame 9 of second 8 to output2/8,9.npy
# Saved frame 10 of second 8 to output2/8,10.npy
# Saved frame 11 of second 8 to output2/8,11.npy
# Saved frame 12 of second 8 to output2/8,12.npy
# Saved frame 13 of second 8 to output2/8,13.npy
# Saved frame 14 of second 8 to output2/8,14.npy
# Saved frame 15 of second 8 to output2/8,15.npy
# Saved frame 16 of second 8 to output2/8,16.npy
# Saved frame 17 of second 8 to output2/8,17.npy
# Saved frame 18 of second 8 to output2/8,18.npy
# Saved frame 19 of second 8 to output2/8,19.npy
# Saved frame 20 of second 8 to output2/8,20.npy
# Saved frame 21 of second 8 to output2/8,21.npy
# Saved frame 22 of second 8 to output2/8,22.npy
# Saved frame 23 of second 8 to output2/8,23.npy
# Saved frame 24 of second 8 to output2/8,24.npy
# Saved frame 0 of second 9 to output2/9,0.npy
# Saved frame 1 of second 9 to output2/9,1.npy
# Saved frame 2 of second 9 to output2/9,2.npy
# Saved frame 3 of second 9 to output2/9,3.npy
# Saved frame 4 of second 9 to output2/9,4.npy
# Saved frame 5 of second 9 to output2/9,5.npy
# Saved frame 6 of second 9 to output2/9,6.npy
# Saved frame 7 of second 9 to output2/9,7.npy
# Saved frame 8 of second 9 to output2/9,8.npy
# Saved frame 9 of second 9 to output2/9,9.npy
# Saved frame 10 of second 9 to output2/9,10.npy
# Saved frame 11 of second 9 to output2/9,11.npy
# Saved frame 12 of second 9 to output2/9,12.npy
# Saved frame 13 of second 9 to output2/9,13.npy
# Saved frame 14 of second 9 to output2/9,14.npy
# Saved frame 15 of second 9 to output2/9,15.npy
# Saved frame 16 of second 9 to output2/9,16.npy
# Saved frame 17 of second 9 to output2/9,17.npy
# Saved frame 18 of second 9 to output2/9,18.npy
# Saved frame 19 of second 9 to output2/9,19.npy
# Saved frame 20 of second 9 to output2/9,20.npy
# Saved frame 21 of second 9 to output2/9,21.npy
# Saved frame 22 of second 9 to output2/9,22.npy
# Saved frame 23 of second 9 to output2/9,23.npy
# Saved frame 24 of second 9 to output2/9,24.npy
# Saved frame 0 of second 10 to output2/10,0.npy
# Saved frame 1 of second 10 to output2/10,1.npy
# Saved frame 2 of second 10 to output2/10,2.npy
# Saved frame 3 of second 10 to output2/10,3.npy
# Saved frame 4 of second 10 to output2/10,4.npy
# Saved frame 5 of second 10 to output2/10,5.npy
# Saved frame 6 of second 10 to output2/10,6.npy
# Saved frame 7 of second 10 to output2/10,7.npy
# Saved frame 8 of second 10 to output2/10,8.npy
# Saved frame 9 of second 10 to output2/10,9.npy
# Saved frame 10 of second 10 to output2/10,10.npy
# Saved frame 11 of second 10 to output2/10,11.npy
# Saved frame 12 of second 10 to output2/10,12.npy
# Saved frame 13 of second 10 to output2/10,13.npy
# Saved frame 14 of second 10 to output2/10,14.npy
# Saved frame 15 of second 10 to output2/10,15.npy
# Saved frame 16 of second 10 to output2/10,16.npy
# Saved frame 17 of second 10 to output2/10,17.npy
# Saved frame 18 of second 10 to output2/10,18.npy
# Saved frame 19 of second 10 to output2/10,19.npy
# Saved frame 20 of second 10 to output2/10,20.npy
# Saved frame 21 of second 10 to output2/10,21.npy
# Saved frame 22 of second 10 to output2/10,22.npy
# Saved frame 23 of second 10 to output2/10,23.npy
# Saved frame 24 of second 10 to output2/10,24.npy
# Saved frame 0 of second 11 to output2/11,0.npy
# Saved frame 1 of second 11 to output2/11,1.npy
# Saved frame 2 of second 11 to output2/11,2.npy
# Saved frame 3 of second 11 to output2/11,3.npy
# Saved frame 4 of second 11 to output2/11,4.npy
# Saved frame 5 of second 11 to output2/11,5.npy
# Saved frame 6 of second 11 to output2/11,6.npy
# Saved frame 7 of second 11 to output2/11,7.npy
# Saved frame 8 of second 11 to output2/11,8.npy
# Saved frame 9 of second 11 to output2/11,9.npy
# Saved frame 10 of second 11 to output2/11,10.npy
# Saved frame 11 of second 11 to output2/11,11.npy
# Saved frame 12 of second 11 to output2/11,12.npy
# Saved frame 13 of second 11 to output2/11,13.npy
# Saved frame 14 of second 11 to output2/11,14.npy
# Saved frame 15 of second 11 to output2/11,15.npy
# Saved frame 16 of second 11 to output2/11,16.npy
# Saved frame 17 of second 11 to output2/11,17.npy
# Saved frame 18 of second 11 to output2/11,18.npy
# Saved frame 19 of second 11 to output2/11,19.npy
# Saved frame 20 of second 11 to output2/11,20.npy
# Saved frame 21 of second 11 to output2/11,21.npy
# Saved frame 22 of second 11 to output2/11,22.npy
# Saved frame 23 of second 11 to output2/11,23.npy
# Saved frame 24 of second 11 to output2/11,24.npy
# Saved frame 0 of second 12 to output2/12,0.npy
# Saved frame 1 of second 12 to output2/12,1.npy
# Saved frame 2 of second 12 to output2/12,2.npy
# Saved frame 3 of second 12 to output2/12,3.npy
# Saved frame 4 of second 12 to output2/12,4.npy
# Saved frame 5 of second 12 to output2/12,5.npy
# Saved frame 6 of second 12 to output2/12,6.npy
# Saved frame 7 of second 12 to output2/12,7.npy
# Saved frame 8 of second 12 to output2/12,8.npy
# Saved frame 9 of second 12 to output2/12,9.npy
# Saved frame 10 of second 12 to output2/12,10.npy
# Saved frame 11 of second 12 to output2/12,11.npy
# Saved frame 12 of second 12 to output2/12,12.npy
# Saved frame 13 of second 12 to output2/12,13.npy
# Saved frame 14 of second 12 to output2/12,14.npy
# Saved frame 15 of second 12 to output2/12,15.npy
# Saved frame 16 of second 12 to output2/12,16.npy
# Saved frame 17 of second 12 to output2/12,17.npy
# Saved frame 18 of second 12 to output2/12,18.npy
# Saved frame 19 of second 12 to output2/12,19.npy
# Saved frame 20 of second 12 to output2/12,20.npy
# Saved frame 21 of second 12 to output2/12,21.npy
# Saved frame 22 of second 12 to output2/12,22.npy
# Saved frame 23 of second 12 to output2/12,23.npy
# Saved frame 24 of second 12 to output2/12,24.npy
# Saved frame 0 of second 13 to output2/13,0.npy
# Saved frame 1 of second 13 to output2/13,1.npy
# Saved frame 2 of second 13 to output2/13,2.npy
# Saved frame 3 of second 13 to output2/13,3.npy
# Saved frame 4 of second 13 to output2/13,4.npy
# Saved frame 5 of second 13 to output2/13,5.npy
# Saved frame 6 of second 13 to output2/13,6.npy
# Saved frame 7 of second 13 to output2/13,7.npy
# Saved frame 8 of second 13 to output2/13,8.npy
# Saved frame 9 of second 13 to output2/13,9.npy
# Saved frame 10 of second 13 to output2/13,10.npy
# Saved frame 11 of second 13 to output2/13,11.npy
# Saved frame 12 of second 13 to output2/13,12.npy
# Saved frame 13 of second 13 to output2/13,13.npy
# Saved frame 14 of second 13 to output2/13,14.npy
# Saved frame 15 of second 13 to output2/13,15.npy
# Saved frame 16 of second 13 to output2/13,16.npy
# Saved frame 17 of second 13 to output2/13,17.npy
# Saved frame 18 of second 13 to output2/13,18.npy
# Saved frame 19 of second 13 to output2/13,19.npy
# Saved frame 20 of second 13 to output2/13,20.npy
# Saved frame 21 of second 13 to output2/13,21.npy
# Saved frame 22 of second 13 to output2/13,22.npy
# Saved frame 23 of second 13 to output2/13,23.npy
# Saved frame 24 of second 13 to output2/13,24.npy
# Saved frame 0 of second 14 to output2/14,0.npy
# Saved frame 1 of second 14 to output2/14,1.npy
# Saved frame 2 of second 14 to output2/14,2.npy
# Saved frame 3 of second 14 to output2/14,3.npy
# Saved frame 4 of second 14 to output2/14,4.npy
# Saved frame 5 of second 14 to output2/14,5.npy
# Saved frame 6 of second 14 to output2/14,6.npy
# Saved frame 7 of second 14 to output2/14,7.npy
# Saved frame 8 of second 14 to output2/14,8.npy
# Saved frame 9 of second 14 to output2/14,9.npy
# Saved frame 10 of second 14 to output2/14,10.npy
# Saved frame 11 of second 14 to output2/14,11.npy
# Saved frame 12 of second 14 to output2/14,12.npy
# Saved frame 13 of second 14 to output2/14,13.npy
# Saved frame 14 of second 14 to output2/14,14.npy
# Saved frame 15 of second 14 to output2/14,15.npy
# Saved frame 16 of second 14 to output2/14,16.npy
# Saved frame 17 of second 14 to output2/14,17.npy
# Saved frame 18 of second 14 to output2/14,18.npy
# Saved frame 19 of second 14 to output2/14,19.npy
# Saved frame 20 of second 14 to output2/14,20.npy
# Saved frame 21 of second 14 to output2/14,21.npy
# Saved frame 22 of second 14 to output2/14,22.npy
# Saved frame 23 of second 14 to output2/14,23.npy
# Saved frame 24 of second 14 to output2/14,24.npy
# Saved frame 0 of second 15 to output2/15,0.npy
# Saved frame 1 of second 15 to output2/15,1.npy
# Saved frame 2 of second 15 to output2/15,2.npy
# Saved frame 3 of second 15 to output2/15,3.npy
# Saved frame 4 of second 15 to output2/15,4.npy
# Saved frame 5 of second 15 to output2/15,5.npy
# Saved frame 6 of second 15 to output2/15,6.npy
# Saved frame 7 of second 15 to output2/15,7.npy
# Saved frame 8 of second 15 to output2/15,8.npy
# Saved frame 9 of second 15 to output2/15,9.npy
# Saved frame 10 of second 15 to output2/15,10.npy
# Saved frame 11 of second 15 to output2/15,11.npy
# Saved frame 12 of second 15 to output2/15,12.npy
# Saved frame 13 of second 15 to output2/15,13.npy
# Saved frame 14 of second 15 to output2/15,14.npy
# Saved frame 15 of second 15 to output2/15,15.npy
# Saved frame 16 of second 15 to output2/15,16.npy
# Saved frame 17 of second 15 to output2/15,17.npy
# Saved frame 18 of second 15 to output2/15,18.npy
# Saved frame 19 of second 15 to output2/15,19.npy
# Saved frame 20 of second 15 to output2/15,20.npy
# Saved frame 21 of second 15 to output2/15,21.npy
# Saved frame 22 of second 15 to output2/15,22.npy
# Saved frame 23 of second 15 to output2/15,23.npy
# Saved frame 24 of second 15 to output2/15,24.npy
# Saved frame 0 of second 16 to output2/16,0.npy
# Saved frame 1 of second 16 to output2/16,1.npy
# Saved frame 2 of second 16 to output2/16,2.npy
# Saved frame 3 of second 16 to output2/16,3.npy
# Saved frame 4 of second 16 to output2/16,4.npy
# Saved frame 5 of second 16 to output2/16,5.npy
# Saved frame 6 of second 16 to output2/16,6.npy
# Saved frame 7 of second 16 to output2/16,7.npy
# Saved frame 8 of second 16 to output2/16,8.npy
# Saved frame 9 of second 16 to output2/16,9.npy
# Saved frame 10 of second 16 to output2/16,10.npy
# Saved frame 11 of second 16 to output2/16,11.npy
# Saved frame 12 of second 16 to output2/16,12.npy
# Saved frame 13 of second 16 to output2/16,13.npy
# Saved frame 14 of second 16 to output2/16,14.npy
# Saved frame 15 of second 16 to output2/16,15.npy
# Saved frame 16 of second 16 to output2/16,16.npy
# Saved frame 17 of second 16 to output2/16,17.npy
# Saved frame 18 of second 16 to output2/16,18.npy
# Saved frame 19 of second 16 to output2/16,19.npy
# Saved frame 20 of second 16 to output2/16,20.npy
# Saved frame 21 of second 16 to output2/16,21.npy
# Saved frame 22 of second 16 to output2/16,22.npy
# Saved frame 23 of second 16 to output2/16,23.npy
# Saved frame 24 of second 16 to output2/16,24.npy
# Saved frame 0 of second 17 to output2/17,0.npy
# Saved frame 1 of second 17 to output2/17,1.npy
# Saved frame 2 of second 17 to output2/17,2.npy
# Saved frame 3 of second 17 to output2/17,3.npy
# Saved frame 4 of second 17 to output2/17,4.npy
# Saved frame 5 of second 17 to output2/17,5.npy
# Saved frame 6 of second 17 to output2/17,6.npy
# Saved frame 7 of second 17 to output2/17,7.npy
# Saved frame 8 of second 17 to output2/17,8.npy
# Saved frame 9 of second 17 to output2/17,9.npy
# Saved frame 10 of second 17 to output2/17,10.npy
# Saved frame 11 of second 17 to output2/17,11.npy
# Saved frame 12 of second 17 to output2/17,12.npy
# Saved frame 13 of second 17 to output2/17,13.npy
# Saved frame 14 of second 17 to output2/17,14.npy
# Saved frame 15 of second 17 to output2/17,15.npy
# Saved frame 16 of second 17 to output2/17,16.npy
# Saved frame 17 of second 17 to output2/17,17.npy
# Saved frame 18 of second 17 to output2/17,18.npy
# Saved frame 19 of second 17 to output2/17,19.npy
# Saved frame 20 of second 17 to output2/17,20.npy
# Saved frame 21 of second 17 to output2/17,21.npy
# Saved frame 22 of second 17 to output2/17,22.npy
# Saved frame 23 of second 17 to output2/17,23.npy
# Saved frame 24 of second 17 to output2/17,24.npy
# Saved frame 0 of second 18 to output2/18,0.npy
# Saved frame 1 of second 18 to output2/18,1.npy
# Saved frame 2 of second 18 to output2/18,2.npy
# Saved frame 3 of second 18 to output2/18,3.npy
# Saved frame 4 of second 18 to output2/18,4.npy
# Saved frame 5 of second 18 to output2/18,5.npy
# Saved frame 6 of second 18 to output2/18,6.npy
# Saved frame 7 of second 18 to output2/18,7.npy
# Saved frame 8 of second 18 to output2/18,8.npy
# Saved frame 9 of second 18 to output2/18,9.npy
# Saved frame 10 of second 18 to output2/18,10.npy
# Saved frame 11 of second 18 to output2/18,11.npy
# Saved frame 12 of second 18 to output2/18,12.npy
# Saved frame 13 of second 18 to output2/18,13.npy
# Saved frame 14 of second 18 to output2/18,14.npy
# Saved frame 15 of second 18 to output2/18,15.npy
# Saved frame 16 of second 18 to output2/18,16.npy
# Saved frame 17 of second 18 to output2/18,17.npy
# Saved frame 18 of second 18 to output2/18,18.npy
# Saved frame 19 of second 18 to output2/18,19.npy
# Saved frame 20 of second 18 to output2/18,20.npy
# Saved frame 21 of second 18 to output2/18,21.npy
# Saved frame 22 of second 18 to output2/18,22.npy
# Saved frame 23 of second 18 to output2/18,23.npy
# Saved frame 24 of second 18 to output2/18,24.npy
# Saved frame 0 of second 19 to output2/19,0.npy
# Saved frame 1 of second 19 to output2/19,1.npy
# Saved frame 2 of second 19 to output2/19,2.npy
# Saved frame 3 of second 19 to output2/19,3.npy
# Saved frame 4 of second 19 to output2/19,4.npy
# Saved frame 5 of second 19 to output2/19,5.npy
# Saved frame 6 of second 19 to output2/19,6.npy
# Saved frame 7 of second 19 to output2/19,7.npy
# Saved frame 8 of second 19 to output2/19,8.npy
# Saved frame 9 of second 19 to output2/19,9.npy
# Saved frame 10 of second 19 to output2/19,10.npy
# Saved frame 11 of second 19 to output2/19,11.npy
# Saved frame 12 of second 19 to output2/19,12.npy
# Saved frame 13 of second 19 to output2/19,13.npy
# Saved frame 14 of second 19 to output2/19,14.npy
# Saved frame 15 of second 19 to output2/19,15.npy
# Saved frame 16 of second 19 to output2/19,16.npy
# Saved frame 17 of second 19 to output2/19,17.npy
# Saved frame 18 of second 19 to output2/19,18.npy
# Saved frame 19 of second 19 to output2/19,19.npy
# Saved frame 20 of second 19 to output2/19,20.npy
# Saved frame 21 of second 19 to output2/19,21.npy
# Saved frame 22 of second 19 to output2/19,22.npy
# Saved frame 23 of second 19 to output2/19,23.npy
# Saved frame 24 of second 19 to output2/19,24.npy
# Saved frame 0 of second 20 to output2/20,0.npy
# Saved frame 1 of second 20 to output2/20,1.npy
# Saved frame 2 of second 20 to output2/20,2.npy
# Saved frame 3 of second 20 to output2/20,3.npy
# Saved frame 4 of second 20 to output2/20,4.npy
# Saved frame 5 of second 20 to output2/20,5.npy
# Saved frame 6 of second 20 to output2/20,6.npy
# Saved frame 7 of second 20 to output2/20,7.npy
# Saved frame 8 of second 20 to output2/20,8.npy
# Saved frame 9 of second 20 to output2/20,9.npy
# Saved frame 10 of second 20 to output2/20,10.npy
# Saved frame 11 of second 20 to output2/20,11.npy
# Saved frame 12 of second 20 to output2/20,12.npy
# Saved frame 13 of second 20 to output2/20,13.npy
# Saved frame 14 of second 20 to output2/20,14.npy
# Saved frame 15 of second 20 to output2/20,15.npy
# Saved frame 16 of second 20 to output2/20,16.npy
# Saved frame 17 of second 20 to output2/20,17.npy
# Saved frame 18 of second 20 to output2/20,18.npy
# Saved frame 19 of second 20 to output2/20,19.npy
# Saved frame 20 of second 20 to output2/20,20.npy
# Saved frame 21 of second 20 to output2/20,21.npy
# Saved frame 22 of second 20 to output2/20,22.npy
# Saved frame 23 of second 20 to output2/20,23.npy
# Saved frame 24 of second 20 to output2/20,24.npy
# Saved frame 0 of second 21 to output2/21,0.npy
# Saved frame 1 of second 21 to output2/21,1.npy
# Saved frame 2 of second 21 to output2/21,2.npy
# Saved frame 3 of second 21 to output2/21,3.npy
# Saved frame 4 of second 21 to output2/21,4.npy
# Saved frame 5 of second 21 to output2/21,5.npy
# Saved frame 6 of second 21 to output2/21,6.npy
# Saved frame 7 of second 21 to output2/21,7.npy
# Saved frame 8 of second 21 to output2/21,8.npy
# Saved frame 9 of second 21 to output2/21,9.npy
# Saved frame 10 of second 21 to output2/21,10.npy
# Saved frame 11 of second 21 to output2/21,11.npy
# Saved frame 12 of second 21 to output2/21,12.npy
# Saved frame 13 of second 21 to output2/21,13.npy
# Saved frame 14 of second 21 to output2/21,14.npy
# Saved frame 15 of second 21 to output2/21,15.npy
# Saved frame 16 of second 21 to output2/21,16.npy
# Saved frame 17 of second 21 to output2/21,17.npy
# Saved frame 18 of second 21 to output2/21,18.npy
# Saved frame 19 of second 21 to output2/21,19.npy
# Saved frame 20 of second 21 to output2/21,20.npy
# Saved frame 21 of second 21 to output2/21,21.npy
# Saved frame 22 of second 21 to output2/21,22.npy
# Saved frame 23 of second 21 to output2/21,23.npy
# Saved frame 24 of second 21 to output2/21,24.npy
# Saved frame 0 of second 22 to output2/22,0.npy
# Saved frame 1 of second 22 to output2/22,1.npy
# Saved frame 2 of second 22 to output2/22,2.npy
# Saved frame 3 of second 22 to output2/22,3.npy
# Saved frame 4 of second 22 to output2/22,4.npy
# Saved frame 5 of second 22 to output2/22,5.npy
# Saved frame 6 of second 22 to output2/22,6.npy
# Saved frame 7 of second 22 to output2/22,7.npy
# Saved frame 8 of second 22 to output2/22,8.npy
# Saved frame 9 of second 22 to output2/22,9.npy
# Saved frame 10 of second 22 to output2/22,10.npy
# Saved frame 11 of second 22 to output2/22,11.npy
# Saved frame 12 of second 22 to output2/22,12.npy
# Saved frame 13 of second 22 to output2/22,13.npy
# Saved frame 14 of second 22 to output2/22,14.npy
# Saved frame 15 of second 22 to output2/22,15.npy
# Saved frame 16 of second 22 to output2/22,16.npy
# Saved frame 17 of second 22 to output2/22,17.npy
# Saved frame 18 of second 22 to output2/22,18.npy
# Saved frame 19 of second 22 to output2/22,19.npy
# Saved frame 20 of second 22 to output2/22,20.npy
# Saved frame 21 of second 22 to output2/22,21.npy
# Saved frame 22 of second 22 to output2/22,22.npy
# Saved frame 23 of second 22 to output2/22,23.npy
# Saved frame 24 of second 22 to output2/22,24.npy
# Saved frame 0 of second 23 to output2/23,0.npy
# Saved frame 1 of second 23 to output2/23,1.npy
# Saved frame 2 of second 23 to output2/23,2.npy
# Saved frame 3 of second 23 to output2/23,3.npy
# Saved frame 4 of second 23 to output2/23,4.npy
# Saved frame 5 of second 23 to output2/23,5.npy
# Saved frame 6 of second 23 to output2/23,6.npy
# Saved frame 7 of second 23 to output2/23,7.npy
# Saved frame 8 of second 23 to output2/23,8.npy
# Saved frame 9 of second 23 to output2/23,9.npy
# Saved frame 10 of second 23 to output2/23,10.npy
# Saved frame 11 of second 23 to output2/23,11.npy
# Saved frame 12 of second 23 to output2/23,12.npy
# Saved frame 13 of second 23 to output2/23,13.npy
# Saved frame 14 of second 23 to output2/23,14.npy
# Saved frame 15 of second 23 to output2/23,15.npy
# Saved frame 16 of second 23 to output2/23,16.npy
# Saved frame 17 of second 23 to output2/23,17.npy
# Saved frame 18 of second 23 to output2/23,18.npy
# Saved frame 19 of second 23 to output2/23,19.npy
# Saved frame 20 of second 23 to output2/23,20.npy
# Saved frame 21 of second 23 to output2/23,21.npy
# Saved frame 22 of second 23 to output2/23,22.npy
# Saved frame 23 of second 23 to output2/23,23.npy
# Saved frame 24 of second 23 to output2/23,24.npy
# Saved frame 0 of second 24 to output2/24,0.npy
# Saved frame 1 of second 24 to output2/24,1.npy
# Saved frame 2 of second 24 to output2/24,2.npy
# Saved frame 3 of second 24 to output2/24,3.npy
# Saved frame 4 of second 24 to output2/24,4.npy
# Saved frame 5 of second 24 to output2/24,5.npy
# Saved frame 6 of second 24 to output2/24,6.npy
# Saved frame 7 of second 24 to output2/24,7.npy
# Saved frame 8 of second 24 to output2/24,8.npy
# Saved frame 9 of second 24 to output2/24,9.npy
# Saved frame 10 of second 24 to output2/24,10.npy
# Saved frame 11 of second 24 to output2/24,11.npy
# Saved frame 12 of second 24 to output2/24,12.npy
# Saved frame 13 of second 24 to output2/24,13.npy
# Saved frame 14 of second 24 to output2/24,14.npy
# Saved frame 15 of second 24 to output2/24,15.npy
# Saved frame 16 of second 24 to output2/24,16.npy
# Saved frame 17 of second 24 to output2/24,17.npy
# Saved frame 18 of second 24 to output2/24,18.npy
# Saved frame 19 of second 24 to output2/24,19.npy
# Saved frame 20 of second 24 to output2/24,20.npy
# Saved frame 21 of second 24 to output2/24,21.npy
# Saved frame 22 of second 24 to output2/24,22.npy
# Saved frame 23 of second 24 to output2/24,23.npy
# Saved frame 24 of second 24 to output2/24,24.npy
# Saved frame 0 of second 25 to output2/25,0.npy
# Saved frame 1 of second 25 to output2/25,1.npy
# Saved frame 2 of second 25 to output2/25,2.npy
# Saved frame 3 of second 25 to output2/25,3.npy
# Saved frame 4 of second 25 to output2/25,4.npy
# Saved frame 5 of second 25 to output2/25,5.npy
# Saved frame 6 of second 25 to output2/25,6.npy
# Saved frame 7 of second 25 to output2/25,7.npy
# Saved frame 8 of second 25 to output2/25,8.npy
# Saved frame 9 of second 25 to output2/25,9.npy
# Saved frame 10 of second 25 to output2/25,10.npy
# Saved frame 11 of second 25 to output2/25,11.npy
# Saved frame 12 of second 25 to output2/25,12.npy
# Saved frame 13 of second 25 to output2/25,13.npy
# Saved frame 14 of second 25 to output2/25,14.npy
# Saved frame 15 of second 25 to output2/25,15.npy
# Saved frame 16 of second 25 to output2/25,16.npy
# Saved frame 17 of second 25 to output2/25,17.npy
# Saved frame 18 of second 25 to output2/25,18.npy
# Saved frame 19 of second 25 to output2/25,19.npy
# Saved frame 20 of second 25 to output2/25,20.npy
# Saved frame 21 of second 25 to output2/25,21.npy
# Saved frame 22 of second 25 to output2/25,22.npy
# Saved frame 23 of second 25 to output2/25,23.npy
# Saved frame 24 of second 25 to output2/25,24.npy
# Saved frame 0 of second 26 to output2/26,0.npy
# Saved frame 1 of second 26 to output2/26,1.npy
# Saved frame 2 of second 26 to output2/26,2.npy
# Saved frame 3 of second 26 to output2/26,3.npy
# Saved frame 4 of second 26 to output2/26,4.npy
# Saved frame 5 of second 26 to output2/26,5.npy
# Saved frame 6 of second 26 to output2/26,6.npy
# Saved frame 7 of second 26 to output2/26,7.npy
# Saved frame 8 of second 26 to output2/26,8.npy
# Saved frame 9 of second 26 to output2/26,9.npy
# Saved frame 10 of second 26 to output2/26,10.npy
# Saved frame 11 of second 26 to output2/26,11.npy
# Saved frame 12 of second 26 to output2/26,12.npy
# Saved frame 13 of second 26 to output2/26,13.npy
# Saved frame 14 of second 26 to output2/26,14.npy
# Saved frame 15 of second 26 to output2/26,15.npy
# Saved frame 16 of second 26 to output2/26,16.npy
# Saved frame 17 of second 26 to output2/26,17.npy
# Saved frame 18 of second 26 to output2/26,18.npy
# Saved frame 19 of second 26 to output2/26,19.npy
# Saved frame 20 of second 26 to output2/26,20.npy
# Saved frame 21 of second 26 to output2/26,21.npy
# Saved frame 22 of second 26 to output2/26,22.npy
# Saved frame 23 of second 26 to output2/26,23.npy
# Saved frame 24 of second 26 to output2/26,24.npy
# Saved frame 0 of second 27 to output2/27,0.npy
# Saved frame 1 of second 27 to output2/27,1.npy
# Saved frame 2 of second 27 to output2/27,2.npy
# Saved frame 3 of second 27 to output2/27,3.npy
# Saved frame 4 of second 27 to output2/27,4.npy
# Saved frame 5 of second 27 to output2/27,5.npy
# Saved frame 6 of second 27 to output2/27,6.npy
# Saved frame 7 of second 27 to output2/27,7.npy
# Saved frame 8 of second 27 to output2/27,8.npy
# Saved frame 9 of second 27 to output2/27,9.npy
# Saved frame 10 of second 27 to output2/27,10.npy
# Saved frame 11 of second 27 to output2/27,11.npy
# Saved frame 12 of second 27 to output2/27,12.npy
# Saved frame 13 of second 27 to output2/27,13.npy
# Saved frame 14 of second 27 to output2/27,14.npy
# Saved frame 15 of second 27 to output2/27,15.npy
# Saved frame 16 of second 27 to output2/27,16.npy
# Saved frame 17 of second 27 to output2/27,17.npy
# Saved frame 18 of second 27 to output2/27,18.npy
# Saved frame 19 of second 27 to output2/27,19.npy
# Saved frame 20 of second 27 to output2/27,20.npy
# Saved frame 21 of second 27 to output2/27,21.npy
# Saved frame 22 of second 27 to output2/27,22.npy
# Saved frame 23 of second 27 to output2/27,23.npy
# Saved frame 24 of second 27 to output2/27,24.npy
# Saved frame 0 of second 28 to output2/28,0.npy
# Saved frame 1 of second 28 to output2/28,1.npy
# Saved frame 2 of second 28 to output2/28,2.npy
# Saved frame 3 of second 28 to output2/28,3.npy
# Saved frame 4 of second 28 to output2/28,4.npy
# Saved frame 5 of second 28 to output2/28,5.npy
# Saved frame 6 of second 28 to output2/28,6.npy
# Saved frame 7 of second 28 to output2/28,7.npy
# Saved frame 8 of second 28 to output2/28,8.npy
# Saved frame 9 of second 28 to output2/28,9.npy
# Saved frame 10 of second 28 to output2/28,10.npy
# Saved frame 11 of second 28 to output2/28,11.npy
# Saved frame 12 of second 28 to output2/28,12.npy
# Saved frame 13 of second 28 to output2/28,13.npy
# Saved frame 14 of second 28 to output2/28,14.npy
# Saved frame 15 of second 28 to output2/28,15.npy
# Saved frame 16 of second 28 to output2/28,16.npy
# Saved frame 17 of second 28 to output2/28,17.npy
# Saved frame 18 of second 28 to output2/28,18.npy
# Saved frame 19 of second 28 to output2/28,19.npy
# Saved frame 20 of second 28 to output2/28,20.npy
# Saved frame 21 of second 28 to output2/28,21.npy
# Saved frame 22 of second 28 to output2/28,22.npy
# Saved frame 23 of second 28 to output2/28,23.npy
# Saved frame 24 of second 28 to output2/28,24.npy
# Saved frame 0 of second 29 to output2/29,0.npy
# Saved frame 1 of second 29 to output2/29,1.npy
# Saved frame 2 of second 29 to output2/29,2.npy
# Saved frame 3 of second 29 to output2/29,3.npy
# Saved frame 4 of second 29 to output2/29,4.npy
# Saved frame 5 of second 29 to output2/29,5.npy
# Saved frame 6 of second 29 to output2/29,6.npy
# Saved frame 7 of second 29 to output2/29,7.npy
# Saved frame 8 of second 29 to output2/29,8.npy
# Saved frame 9 of second 29 to output2/29,9.npy
# Saved frame 10 of second 29 to output2/29,10.npy
# Saved frame 11 of second 29 to output2/29,11.npy
# Saved frame 12 of second 29 to output2/29,12.npy
# Saved frame 13 of second 29 to output2/29,13.npy
# Saved frame 14 of second 29 to output2/29,14.npy
# Saved frame 15 of second 29 to output2/29,15.npy
# Saved frame 16 of second 29 to output2/29,16.npy
# Saved frame 17 of second 29 to output2/29,17.npy
# Saved frame 18 of second 29 to output2/29,18.npy
# Saved frame 19 of second 29 to output2/29,19.npy
# Saved frame 20 of second 29 to output2/29,20.npy
# Saved frame 21 of second 29 to output2/29,21.npy
# Saved frame 22 of second 29 to output2/29,22.npy
# Saved frame 23 of second 29 to output2/29,23.npy
# Saved frame 24 of second 29 to output2/29,24.npy
# Saved frame 0 of second 30 to output2/30,0.npy
# Saved frame 1 of second 30 to output2/30,1.npy
# Saved frame 2 of second 30 to output2/30,2.npy
# Saved frame 3 of second 30 to output2/30,3.npy
# Saved frame 4 of second 30 to output2/30,4.npy
# Saved frame 5 of second 30 to output2/30,5.npy
# Saved frame 6 of second 30 to output2/30,6.npy
# Saved frame 7 of second 30 to output2/30,7.npy
# Saved frame 8 of second 30 to output2/30,8.npy
# Saved frame 9 of second 30 to output2/30,9.npy
# Saved frame 10 of second 30 to output2/30,10.npy
# Saved frame 11 of second 30 to output2/30,11.npy
# Saved frame 12 of second 30 to output2/30,12.npy
# Saved frame 13 of second 30 to output2/30,13.npy
# Saved frame 14 of second 30 to output2/30,14.npy
# Saved frame 15 of second 30 to output2/30,15.npy
# Saved frame 16 of second 30 to output2/30,16.npy
# Saved frame 17 of second 30 to output2/30,17.npy
# Saved frame 18 of second 30 to output2/30,18.npy
# Saved frame 19 of second 30 to output2/30,19.npy
# Saved frame 20 of second 30 to output2/30,20.npy
# Saved frame 21 of second 30 to output2/30,21.npy
# Saved frame 22 of second 30 to output2/30,22.npy
# Saved frame 23 of second 30 to output2/30,23.npy
# Saved frame 24 of second 30 to output2/30,24.npy
# Saved frame 0 of second 31 to output2/31,0.npy
# Saved frame 1 of second 31 to output2/31,1.npy
# Saved frame 2 of second 31 to output2/31,2.npy
# Saved frame 3 of second 31 to output2/31,3.npy
# Saved frame 4 of second 31 to output2/31,4.npy
# Saved frame 5 of second 31 to output2/31,5.npy
# Saved frame 6 of second 31 to output2/31,6.npy
# Saved frame 7 of second 31 to output2/31,7.npy
# Saved frame 8 of second 31 to output2/31,8.npy
# Saved frame 9 of second 31 to output2/31,9.npy
# Saved frame 10 of second 31 to output2/31,10.npy
# Saved frame 11 of second 31 to output2/31,11.npy
# Saved frame 12 of second 31 to output2/31,12.npy
# Saved frame 13 of second 31 to output2/31,13.npy
# Saved frame 14 of second 31 to output2/31,14.npy
# Saved frame 15 of second 31 to output2/31,15.npy
# Saved frame 16 of second 31 to output2/31,16.npy
# Saved frame 17 of second 31 to output2/31,17.npy
# Saved frame 18 of second 31 to output2/31,18.npy
# Saved frame 19 of second 31 to output2/31,19.npy
# Saved frame 20 of second 31 to output2/31,20.npy
# Saved frame 21 of second 31 to output2/31,21.npy
# Saved frame 22 of second 31 to output2/31,22.npy
# Saved frame 23 of second 31 to output2/31,23.npy
# Saved frame 24 of second 31 to output2/31,24.npy
# Saved frame 0 of second 32 to output2/32,0.npy
# Saved frame 1 of second 32 to output2/32,1.npy
# Saved frame 2 of second 32 to output2/32,2.npy
# Saved frame 3 of second 32 to output2/32,3.npy
# Saved frame 4 of second 32 to output2/32,4.npy
# Saved frame 5 of second 32 to output2/32,5.npy
# Saved frame 6 of second 32 to output2/32,6.npy
# Saved frame 7 of second 32 to output2/32,7.npy
# Saved frame 8 of second 32 to output2/32,8.npy
# Saved frame 9 of second 32 to output2/32,9.npy
# Saved frame 10 of second 32 to output2/32,10.npy
# Saved frame 11 of second 32 to output2/32,11.npy
# Saved frame 12 of second 32 to output2/32,12.npy
# Saved frame 13 of second 32 to output2/32,13.npy
# Saved frame 14 of second 32 to output2/32,14.npy
# Saved frame 15 of second 32 to output2/32,15.npy
# Saved frame 16 of second 32 to output2/32,16.npy
# Saved frame 17 of second 32 to output2/32,17.npy
# Saved frame 18 of second 32 to output2/32,18.npy
# Saved frame 19 of second 32 to output2/32,19.npy
# Saved frame 20 of second 32 to output2/32,20.npy
# Saved frame 21 of second 32 to output2/32,21.npy
# Saved frame 22 of second 32 to output2/32,22.npy
# Saved frame 23 of second 32 to output2/32,23.npy
# Saved frame 24 of second 32 to output2/32,24.npy
# Saved frame 0 of second 33 to output2/33,0.npy
# Saved frame 1 of second 33 to output2/33,1.npy
# Saved frame 2 of second 33 to output2/33,2.npy
# Saved frame 3 of second 33 to output2/33,3.npy
# Saved frame 4 of second 33 to output2/33,4.npy
# Saved frame 5 of second 33 to output2/33,5.npy
# Saved frame 6 of second 33 to output2/33,6.npy
# Saved frame 7 of second 33 to output2/33,7.npy
# Saved frame 8 of second 33 to output2/33,8.npy
# Saved frame 9 of second 33 to output2/33,9.npy
# Saved frame 10 of second 33 to output2/33,10.npy
# Saved frame 11 of second 33 to output2/33,11.npy
# Saved frame 12 of second 33 to output2/33,12.npy
# Saved frame 13 of second 33 to output2/33,13.npy
# Saved frame 14 of second 33 to output2/33,14.npy
# Saved frame 15 of second 33 to output2/33,15.npy
# Saved frame 16 of second 33 to output2/33,16.npy
# Saved frame 17 of second 33 to output2/33,17.npy
# Saved frame 18 of second 33 to output2/33,18.npy
# Saved frame 19 of second 33 to output2/33,19.npy
# Saved frame 20 of second 33 to output2/33,20.npy
# Saved frame 21 of second 33 to output2/33,21.npy
# Saved frame 22 of second 33 to output2/33,22.npy
# Saved frame 23 of second 33 to output2/33,23.npy
# Saved frame 24 of second 33 to output2/33,24.npy
# Saved frame 0 of second 34 to output2/34,0.npy
# Saved frame 1 of second 34 to output2/34,1.npy
# Saved frame 2 of second 34 to output2/34,2.npy
# Saved frame 3 of second 34 to output2/34,3.npy
# Saved frame 4 of second 34 to output2/34,4.npy
# Saved frame 5 of second 34 to output2/34,5.npy
# Saved frame 6 of second 34 to output2/34,6.npy
# Saved frame 7 of second 34 to output2/34,7.npy
# Saved frame 8 of second 34 to output2/34,8.npy
# Saved frame 9 of second 34 to output2/34,9.npy
# Saved frame 10 of second 34 to output2/34,10.npy
# Saved frame 11 of second 34 to output2/34,11.npy
# Saved frame 12 of second 34 to output2/34,12.npy
# Saved frame 13 of second 34 to output2/34,13.npy
# Saved frame 14 of second 34 to output2/34,14.npy
# Saved frame 15 of second 34 to output2/34,15.npy
# Saved frame 16 of second 34 to output2/34,16.npy
# Saved frame 17 of second 34 to output2/34,17.npy
# Saved frame 18 of second 34 to output2/34,18.npy
# Saved frame 19 of second 34 to output2/34,19.npy
# Saved frame 20 of second 34 to output2/34,20.npy
# Saved frame 21 of second 34 to output2/34,21.npy
# Saved frame 22 of second 34 to output2/34,22.npy
# Saved frame 23 of second 34 to output2/34,23.npy
# Saved frame 24 of second 34 to output2/34,24.npy
# Saved frame 0 of second 35 to output2/35,0.npy
# Saved frame 1 of second 35 to output2/35,1.npy
# Saved frame 2 of second 35 to output2/35,2.npy
# Saved frame 3 of second 35 to output2/35,3.npy
# Saved frame 4 of second 35 to output2/35,4.npy
# Saved frame 5 of second 35 to output2/35,5.npy
# Saved frame 6 of second 35 to output2/35,6.npy
# Saved frame 7 of second 35 to output2/35,7.npy
# Saved frame 8 of second 35 to output2/35,8.npy
# Saved frame 9 of second 35 to output2/35,9.npy
# Saved frame 10 of second 35 to output2/35,10.npy
# Saved frame 11 of second 35 to output2/35,11.npy
# Saved frame 12 of second 35 to output2/35,12.npy
# Saved frame 13 of second 35 to output2/35,13.npy
# Saved frame 14 of second 35 to output2/35,14.npy
# Saved frame 15 of second 35 to output2/35,15.npy
# Saved frame 16 of second 35 to output2/35,16.npy
# Saved frame 17 of second 35 to output2/35,17.npy
# Saved frame 18 of second 35 to output2/35,18.npy
# Saved frame 19 of second 35 to output2/35,19.npy
# Saved frame 20 of second 35 to output2/35,20.npy
# Saved frame 21 of second 35 to output2/35,21.npy
# Saved frame 22 of second 35 to output2/35,22.npy
# Saved frame 23 of second 35 to output2/35,23.npy
# Saved frame 24 of second 35 to output2/35,24.npy
# Saved frame 0 of second 36 to output2/36,0.npy
# Saved frame 1 of second 36 to output2/36,1.npy
# Saved frame 2 of second 36 to output2/36,2.npy
# Saved frame 3 of second 36 to output2/36,3.npy
# Saved frame 4 of second 36 to output2/36,4.npy
# Saved frame 5 of second 36 to output2/36,5.npy
# Saved frame 6 of second 36 to output2/36,6.npy
# Saved frame 7 of second 36 to output2/36,7.npy
# Saved frame 8 of second 36 to output2/36,8.npy
# Saved frame 9 of second 36 to output2/36,9.npy
# Saved frame 10 of second 36 to output2/36,10.npy
# Saved frame 11 of second 36 to output2/36,11.npy
# Saved frame 12 of second 36 to output2/36,12.npy
# Saved frame 13 of second 36 to output2/36,13.npy
# Saved frame 14 of second 36 to output2/36,14.npy
# Saved frame 15 of second 36 to output2/36,15.npy
# Saved frame 16 of second 36 to output2/36,16.npy
# Saved frame 17 of second 36 to output2/36,17.npy
# Saved frame 18 of second 36 to output2/36,18.npy
# Saved frame 19 of second 36 to output2/36,19.npy
# Saved frame 20 of second 36 to output2/36,20.npy
# Saved frame 21 of second 36 to output2/36,21.npy
# Saved frame 22 of second 36 to output2/36,22.npy
# Saved frame 23 of second 36 to output2/36,23.npy
# Saved frame 24 of second 36 to output2/36,24.npy
# Saved frame 0 of second 37 to output2/37,0.npy
# Saved frame 1 of second 37 to output2/37,1.npy
# Saved frame 2 of second 37 to output2/37,2.npy
# Saved frame 3 of second 37 to output2/37,3.npy
# Saved frame 4 of second 37 to output2/37,4.npy
# Saved frame 5 of second 37 to output2/37,5.npy
# Saved frame 6 of second 37 to output2/37,6.npy
# Saved frame 7 of second 37 to output2/37,7.npy
# Saved frame 8 of second 37 to output2/37,8.npy
# Saved frame 9 of second 37 to output2/37,9.npy
# Saved frame 10 of second 37 to output2/37,10.npy
# Saved frame 11 of second 37 to output2/37,11.npy
# Saved frame 12 of second 37 to output2/37,12.npy
# Saved frame 13 of second 37 to output2/37,13.npy
# Saved frame 14 of second 37 to output2/37,14.npy
# Saved frame 15 of second 37 to output2/37,15.npy
# Saved frame 16 of second 37 to output2/37,16.npy
# Saved frame 17 of second 37 to output2/37,17.npy
# Saved frame 18 of second 37 to output2/37,18.npy
# Saved frame 19 of second 37 to output2/37,19.npy
# Saved frame 20 of second 37 to output2/37,20.npy
# Saved frame 21 of second 37 to output2/37,21.npy
# Saved frame 22 of second 37 to output2/37,22.npy
# Saved frame 23 of second 37 to output2/37,23.npy
# Saved frame 24 of second 37 to output2/37,24.npy
# Saved frame 0 of second 38 to output2/38,0.npy
# Saved frame 1 of second 38 to output2/38,1.npy
# Saved frame 2 of second 38 to output2/38,2.npy
# Saved frame 3 of second 38 to output2/38,3.npy
# Saved frame 4 of second 38 to output2/38,4.npy
# Saved frame 5 of second 38 to output2/38,5.npy
# Saved frame 6 of second 38 to output2/38,6.npy
# Saved frame 7 of second 38 to output2/38,7.npy
# Saved frame 8 of second 38 to output2/38,8.npy
# Saved frame 9 of second 38 to output2/38,9.npy
# Saved frame 10 of second 38 to output2/38,10.npy
# Saved frame 11 of second 38 to output2/38,11.npy
# Saved frame 12 of second 38 to output2/38,12.npy
# Saved frame 13 of second 38 to output2/38,13.npy
# Saved frame 14 of second 38 to output2/38,14.npy
# Saved frame 15 of second 38 to output2/38,15.npy
# Saved frame 16 of second 38 to output2/38,16.npy
# Saved frame 17 of second 38 to output2/38,17.npy
# Saved frame 18 of second 38 to output2/38,18.npy
# Saved frame 19 of second 38 to output2/38,19.npy
# Saved frame 20 of second 38 to output2/38,20.npy
# Saved frame 21 of second 38 to output2/38,21.npy
# Saved frame 22 of second 38 to output2/38,22.npy
# Saved frame 23 of second 38 to output2/38,23.npy
# Saved frame 24 of second 38 to output2/38,24.npy
# Saved frame 0 of second 39 to output2/39,0.npy
# Saved frame 1 of second 39 to output2/39,1.npy
# Saved frame 2 of second 39 to output2/39,2.npy
# Saved frame 3 of second 39 to output2/39,3.npy
# Saved frame 4 of second 39 to output2/39,4.npy
# Saved frame 5 of second 39 to output2/39,5.npy
# Saved frame 6 of second 39 to output2/39,6.npy
# Saved frame 7 of second 39 to output2/39,7.npy
# Saved frame 8 of second 39 to output2/39,8.npy
# Saved frame 9 of second 39 to output2/39,9.npy
# Saved frame 10 of second 39 to output2/39,10.npy
# Saved frame 11 of second 39 to output2/39,11.npy
# Saved frame 12 of second 39 to output2/39,12.npy
# Saved frame 13 of second 39 to output2/39,13.npy
# Saved frame 14 of second 39 to output2/39,14.npy
# Saved frame 15 of second 39 to output2/39,15.npy
# Saved frame 16 of second 39 to output2/39,16.npy
# Saved frame 17 of second 39 to output2/39,17.npy
# Saved frame 18 of second 39 to output2/39,18.npy
# Saved frame 19 of second 39 to output2/39,19.npy
# Saved frame 20 of second 39 to output2/39,20.npy
# Saved frame 21 of second 39 to output2/39,21.npy
# Saved frame 22 of second 39 to output2/39,22.npy
# Saved frame 23 of second 39 to output2/39,23.npy
# Saved frame 24 of second 39 to output2/39,24.npy
# Saved frame 0 of second 40 to output2/40,0.npy
# Saved frame 1 of second 40 to output2/40,1.npy
# Saved frame 2 of second 40 to output2/40,2.npy
# Saved frame 3 of second 40 to output2/40,3.npy
# Saved frame 4 of second 40 to output2/40,4.npy
# Saved frame 5 of second 40 to output2/40,5.npy
# Saved frame 6 of second 40 to output2/40,6.npy
# Saved frame 7 of second 40 to output2/40,7.npy
# Saved frame 8 of second 40 to output2/40,8.npy
# Saved frame 9 of second 40 to output2/40,9.npy
# Saved frame 10 of second 40 to output2/40,10.npy
# Saved frame 11 of second 40 to output2/40,11.npy
# Saved frame 12 of second 40 to output2/40,12.npy
# Saved frame 13 of second 40 to output2/40,13.npy
# Saved frame 14 of second 40 to output2/40,14.npy
# Saved frame 15 of second 40 to output2/40,15.npy
# Saved frame 16 of second 40 to output2/40,16.npy
# Saved frame 17 of second 40 to output2/40,17.npy
# Saved frame 18 of second 40 to output2/40,18.npy
# Saved frame 19 of second 40 to output2/40,19.npy
# Saved frame 20 of second 40 to output2/40,20.npy
# Saved frame 21 of second 40 to output2/40,21.npy
# Saved frame 22 of second 40 to output2/40,22.npy
# Saved frame 23 of second 40 to output2/40,23.npy
# Saved frame 24 of second 40 to output2/40,24.npy
# Saved frame 0 of second 41 to output2/41,0.npy
# Saved frame 1 of second 41 to output2/41,1.npy
# Saved frame 2 of second 41 to output2/41,2.npy
# Saved frame 3 of second 41 to output2/41,3.npy
# Saved frame 4 of second 41 to output2/41,4.npy
# Saved frame 5 of second 41 to output2/41,5.npy
# Saved frame 6 of second 41 to output2/41,6.npy
# Saved frame 7 of second 41 to output2/41,7.npy
# Saved frame 8 of second 41 to output2/41,8.npy
# Saved frame 9 of second 41 to output2/41,9.npy
# Saved frame 10 of second 41 to output2/41,10.npy
# Saved frame 11 of second 41 to output2/41,11.npy
# Saved frame 12 of second 41 to output2/41,12.npy
# Saved frame 13 of second 41 to output2/41,13.npy
# Saved frame 14 of second 41 to output2/41,14.npy
# Saved frame 15 of second 41 to output2/41,15.npy
# Saved frame 16 of second 41 to output2/41,16.npy
# Saved frame 17 of second 41 to output2/41,17.npy
# Saved frame 18 of second 41 to output2/41,18.npy
# Saved frame 19 of second 41 to output2/41,19.npy
# Saved frame 20 of second 41 to output2/41,20.npy
# Saved frame 21 of second 41 to output2/41,21.npy
# Saved frame 22 of second 41 to output2/41,22.npy
# Saved frame 23 of second 41 to output2/41,23.npy
# Saved frame 24 of second 41 to output2/41,24.npy
# Saved frame 0 of second 42 to output2/42,0.npy
# Saved frame 1 of second 42 to output2/42,1.npy
# Saved frame 2 of second 42 to output2/42,2.npy
# Saved frame 3 of second 42 to output2/42,3.npy
# Saved frame 4 of second 42 to output2/42,4.npy
# Saved frame 5 of second 42 to output2/42,5.npy
# Saved frame 6 of second 42 to output2/42,6.npy
# Saved frame 7 of second 42 to output2/42,7.npy
# Saved frame 8 of second 42 to output2/42,8.npy
# Saved frame 9 of second 42 to output2/42,9.npy
# Saved frame 10 of second 42 to output2/42,10.npy
# Saved frame 11 of second 42 to output2/42,11.npy
# Saved frame 12 of second 42 to output2/42,12.npy
# Saved frame 13 of second 42 to output2/42,13.npy
# Saved frame 14 of second 42 to output2/42,14.npy
# Saved frame 15 of second 42 to output2/42,15.npy
# Saved frame 16 of second 42 to output2/42,16.npy
# Saved frame 17 of second 42 to output2/42,17.npy
# Saved frame 18 of second 42 to output2/42,18.npy
# Saved frame 19 of second 42 to output2/42,19.npy
# Saved frame 20 of second 42 to output2/42,20.npy
# Saved frame 21 of second 42 to output2/42,21.npy
# Saved frame 22 of second 42 to output2/42,22.npy
# Saved frame 23 of second 42 to output2/42,23.npy
# Saved frame 24 of second 42 to output2/42,24.npy
# Saved frame 0 of second 43 to output2/43,0.npy
# Saved frame 1 of second 43 to output2/43,1.npy
# Saved frame 2 of second 43 to output2/43,2.npy
# Saved frame 3 of second 43 to output2/43,3.npy
# Saved frame 4 of second 43 to output2/43,4.npy
# Saved frame 5 of second 43 to output2/43,5.npy
# Saved frame 6 of second 43 to output2/43,6.npy
# Saved frame 7 of second 43 to output2/43,7.npy
# Saved frame 8 of second 43 to output2/43,8.npy
# Saved frame 9 of second 43 to output2/43,9.npy
# Saved frame 10 of second 43 to output2/43,10.npy
# Saved frame 11 of second 43 to output2/43,11.npy
# Saved frame 12 of second 43 to output2/43,12.npy
# Saved frame 13 of second 43 to output2/43,13.npy
# Saved frame 14 of second 43 to output2/43,14.npy
# Saved frame 15 of second 43 to output2/43,15.npy
# Saved frame 16 of second 43 to output2/43,16.npy
# Saved frame 17 of second 43 to output2/43,17.npy
# Saved frame 18 of second 43 to output2/43,18.npy
# Saved frame 19 of second 43 to output2/43,19.npy
# Saved frame 20 of second 43 to output2/43,20.npy
# Saved frame 21 of second 43 to output2/43,21.npy
# Saved frame 22 of second 43 to output2/43,22.npy
# Saved frame 23 of second 43 to output2/43,23.npy
# Saved frame 24 of second 43 to output2/43,24.npy
# Saved frame 0 of second 44 to output2/44,0.npy
# Saved frame 1 of second 44 to output2/44,1.npy
# Saved frame 2 of second 44 to output2/44,2.npy
# Saved frame 3 of second 44 to output2/44,3.npy
# Saved frame 4 of second 44 to output2/44,4.npy
# Saved frame 5 of second 44 to output2/44,5.npy
# Saved frame 6 of second 44 to output2/44,6.npy
# Saved frame 7 of second 44 to output2/44,7.npy
# Saved frame 8 of second 44 to output2/44,8.npy
# Saved frame 9 of second 44 to output2/44,9.npy
# Saved frame 10 of second 44 to output2/44,10.npy
# Saved frame 11 of second 44 to output2/44,11.npy
# Saved frame 12 of second 44 to output2/44,12.npy
# Saved frame 13 of second 44 to output2/44,13.npy
# Saved frame 14 of second 44 to output2/44,14.npy
# Saved frame 15 of second 44 to output2/44,15.npy
# Saved frame 16 of second 44 to output2/44,16.npy
# Saved frame 17 of second 44 to output2/44,17.npy
# Saved frame 18 of second 44 to output2/44,18.npy
# Saved frame 19 of second 44 to output2/44,19.npy
# Saved frame 20 of second 44 to output2/44,20.npy
# Saved frame 21 of second 44 to output2/44,21.npy
# Saved frame 22 of second 44 to output2/44,22.npy
# Saved frame 23 of second 44 to output2/44,23.npy
# Saved frame 24 of second 44 to output2/44,24.npy
# Saved frame 0 of second 45 to output2/45,0.npy
# Saved frame 1 of second 45 to output2/45,1.npy
# Saved frame 2 of second 45 to output2/45,2.npy
# Saved frame 3 of second 45 to output2/45,3.npy
# Saved frame 4 of second 45 to output2/45,4.npy
# Saved frame 5 of second 45 to output2/45,5.npy
# Saved frame 6 of second 45 to output2/45,6.npy
# Saved frame 7 of second 45 to output2/45,7.npy
# Saved frame 8 of second 45 to output2/45,8.npy
# Saved frame 9 of second 45 to output2/45,9.npy
# Saved frame 10 of second 45 to output2/45,10.npy
# Saved frame 11 of second 45 to output2/45,11.npy
# Saved frame 12 of second 45 to output2/45,12.npy
# Saved frame 13 of second 45 to output2/45,13.npy
# Saved frame 14 of second 45 to output2/45,14.npy
# Saved frame 15 of second 45 to output2/45,15.npy
# Saved frame 16 of second 45 to output2/45,16.npy
# Saved frame 17 of second 45 to output2/45,17.npy
# Saved frame 18 of second 45 to output2/45,18.npy
# Saved frame 19 of second 45 to output2/45,19.npy
# Saved frame 20 of second 45 to output2/45,20.npy
# Saved frame 21 of second 45 to output2/45,21.npy
# Saved frame 22 of second 45 to output2/45,22.npy
# Saved frame 23 of second 45 to output2/45,23.npy

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from PIL import Image
import os

class ReduceRedunant:
    # Load MobileNetV2 as feature extractor
    def load_mobilenetv2(self):
        base_model = MobileNetV2(alpha=1.0,include_top=False,weights='imagenet',pooling='avg')
        return Model(inputs=base_model.input, outputs=base_model.output)

    # Function to extract features from image
    def extract_features(self, img, model):
        img = np.expand_dims(img, axis=0)
        img = preprocess_input(img)
        features = model.predict(img, verbose=0)
        return features.flatten()

    # Function to compute similarity and reduce image list to 5 most similar
    def reduce_images(self, images: np.ndarray, num_images: int = 5):
        
        # Initialize MobileNetV2 model
        model = self.load_mobilenetv2()
        
        # Extract features for all images
        image_features = [self.extract_features(img, model) for img in images]
        
        # Calculate cosine similarity matrix
        similarity_matrix = cosine_similarity(image_features)
        
        # Calculate mean similarity for each image (sum of all similarities)
        similarity_scores = np.mean(similarity_matrix, axis=1)
        
        # Print similarity scores for all images
#         for idx, score in enumerate(similarity_scores):
#             print(f"Similarity score for image {idx + 1}: {score}")
        
        # Select the top 'num_images' with the highest similarity scores (without changing order)
        # We pick the indices of the top `num_images` based on similarity scores.
        most_similar_indices = np.argsort(similarity_scores)[:num_images]
        img_list_1=[]
        for idx in most_similar_indices:
            img_list_1.append(images[idx])
        # Return the reduced list of similar images (without sorting by similarity)
        return img_list_1

    # Function to save reduced images to disk
    def save_images(self, images, save_path='reduced_images', num_images=5):
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        
        for i, img in enumerate(images):
            # Convert the image (NumPy array) to a PIL Image object
            img_pil = Image.fromarray((img * 255).astype(np.uint8))  # Assuming images are normalized [0, 1]
            img_pil.save(os.path.join(save_path, f'image_{i+1}.png'))
            
    def generate_test_images(self , num_images=24, image_size=(224, 224, 3)):
        images = []
        for i in range(num_images):
            if i < 10:
                # Create similar images (slight variation)
                base_image = np.random.rand(*image_size) * 0.5 + 0.5  # Base image with mid-level brightness
                # Add small noise to create slight variations
                variation = np.random.rand(*image_size) * 0.1
                images.append(base_image + variation)
            else:
                # Create distinctly different images (e.g., with random noise)
                random_image = np.random.rand(*image_size)
                images.append(random_image)
        
        return np.array(images)
# Out:
# 2024-10-15 19:49:46.386991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 19:49:46.405570: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 19:49:46.411254: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 19:49:46.425118: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-15 19:49:47.928788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
reduced_images = ReduceRedunant()
n2= []
count=0
for i in range(len(n1)):
    n21 = reduced_images.reduce_images(n1[i], 5)
    n2.append(n21)
#     reduced_images.save_images(images=n21, save_path='reduced_images', num_images=5)
    count+=1
    print(count)

# %%
def save_images(image_list, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Initialize the image counter
    image_counter = 1

    # Flatten the list of lists
    for img_sublist in image_list:
        for img in img_sublist:
            # Define the output image path with the current counter value
            img_filename = os.path.join(output_folder, f'image_{image_counter}.jpg')
            
            # Convert the image from a NumPy array (assumed to be in float format) to an 8-bit image
            img_8bit = (img * 255).astype(np.uint8) if img.max() <= 1 else img
            
            # Save the image using OpenCV
            cv2.imwrite(img_filename, img_8bit)
            
            # Increment the counter
            image_counter += 1
            
save_images(n2, 'reduced_images')

# %%
pip install decord transformers einops timm accelerate>=0.26.0

# %%
#pip install decord transformers einops timm accelerate>=0.26.0 sentencepiece -q
#pip install sentencepiece
#importing libraries
import numpy as np
import torch
import torchvision.transforms as T
from decord import VideoReader, cpu
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
import os
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)
class ImageProcessor:
    def __init__(self ,path='OpenGVLab/InternVL2-8B'):
        self.path=path
    
        self.model = AutoModel.from_pretrained(
    self.path,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    use_flash_attn=True,
    trust_remote_code=True).eval().cuda()
        self.tokenizer = AutoTokenizer.from_pretrained( path, trust_remote_code=True, use_fast=False)
    #building transformer
    def build_transform(self , input_size):
        MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
        transform = T.Compose([
            T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
            T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
            T.ToTensor(),
            T.Normalize(mean=MEAN, std=STD)
        ])
        return transform

    #aspect_ratio
    def find_closest_aspect_ratio(self,aspect_ratio, target_ratios, width, height, image_size):
        best_ratio_diff = float('inf')
        best_ratio = (1, 1)
        area = width * height
        for ratio in target_ratios:
            target_aspect_ratio = ratio[0] / ratio[1]
            ratio_diff = abs(aspect_ratio - target_aspect_ratio)
            if ratio_diff < best_ratio_diff:
                best_ratio_diff = ratio_diff
                best_ratio = ratio
            elif ratio_diff == best_ratio_diff:
                if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                    best_ratio = ratio
        return best_ratio

    #preprocessig
    def dynamic_preprocess(self , image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
        orig_width, orig_height = image.size
        aspect_ratio = orig_width / orig_height

        # calculate the existing image aspect ratio
        target_ratios = set(
            (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
            i * j <= max_num and i * j >= min_num)
        target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

        # find the closest aspect ratio to the target
        target_aspect_ratio = self.find_closest_aspect_ratio(aspect_ratio, target_ratios, orig_width, orig_height, image_size)

        # calculate the target width and height
        target_width = image_size * target_aspect_ratio[0]
        target_height = image_size * target_aspect_ratio[1]
        blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

        # resize the image
        resized_img = image.resize((target_width, target_height))
        processed_images = []
        for i in range(blocks):
            box = (
                (i % (target_width // image_size)) * image_size,
                (i // (target_width // image_size)) * image_size,
                ((i % (target_width // image_size)) + 1) * image_size,
                ((i // (target_width // image_size)) + 1) * image_size
            )
            # split the image
            split_img = resized_img.crop(box)
            processed_images.append(split_img)
        assert len(processed_images) == blocks
        if use_thumbnail and len(processed_images) != 1:
            thumbnail_img = image.resize((image_size, image_size))
            processed_images.append(thumbnail_img)
        return processed_images

    #image loading
    def load_image(self , image_file, input_size=448, max_num=12):
        image = Image.open(image_file).convert('RGB')
        transform = self.build_transform(input_size=input_size)
        images = self.dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
        pixel_values = [transform(image) for image in images]
        pixel_values = torch.stack(pixel_values)
        return pixel_values

    #iterating 5 frames
#     def frame_iter(self , img_list,max_images=5):
#         l=[]
#         for img in img_list[:max_images]:
#             pixel_values = self.load_image(img, max_num=12).to(torch.bfloat16).cuda()
#             generation_config = dict(max_new_tokens=1024, do_sample=True) 
#             question = '\nPlease describe what happened in the image shortly.'
#             response = self.model.chat(self.tokenizer, pixel_values, question, generation_config)
#             l.append(response)
#         return l
    def frame_iter(self, img_list, max_images=5):
        concatenated_responses = []  # Final list to hold concatenated responses

        # Process the image list in chunks of max_images (5 by default)
        for i in range(6, len(img_list)-6, max_images):

            # Get the current chunk of images (slice the list for every 5 images)
            current_chunk = img_list[i:i+max_images]
            p1 = self.load_image(current_chunk[0], max_num=12).to(torch.bfloat16).cuda()
            p2 = self.load_image(current_chunk[1], max_num=12).to(torch.bfloat16).cuda()
            p3 = self.load_image(current_chunk[2], max_num=12).to(torch.bfloat16).cuda()
            p4 = self.load_image(current_chunk[3], max_num=12).to(torch.bfloat16).cuda()
            p5 = self.load_image(current_chunk[4], max_num=12).to(torch.bfloat16).cuda()
            # Iterate over the images in the current chunk and generate responses
            pixel_values = torch.cat((p1,p2,p3,p4,p5), dim=0)
            generation_config = dict(max_new_tokens=1024, do_sample=True)
            question = '\nPlease describe what happened in the image shortly.'
            response = self.model.chat(self.tokenizer, pixel_values, question, generation_config)

            # Concatenate all responses for this chunk and add to the final list
            concatenated_responses.append(response)

        return concatenated_responses

# %%
paths_list=[]
for img_path in os.listdir('reduced_images'):
    paths_list.append(os.path.join('reduced_images', img_path))

# %%
captions_fps = ImageProcessor().frame_iter(paths_list)
# Out:
# InternLM2ForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# FlashAttention2 is not installed.
# Warning: Flash attention is not available, using eager attention instead.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (11577 > 8192). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 captions_fps = ImageProcessor().frame_iter(paths_list)
#
# Cell In[2], line 126, in ImageProcessor.frame_iter(self, img_list, max_images)
#     124 generation_config = dict(max_new_tokens=1024, do_sample=True)
#     125 question = '\nPlease describe what happened in the image shortly.'
# --> 126 response = self.model.chat(self.tokenizer, pixel_values, question, generation_config)
#     128 # Concatenate all responses for this chunk and add to the final list
#     129 concatenated_responses.append(responses)
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internvl_chat.py:290, in InternVLChatModel.chat(self, tokenizer, pixel_values, question, generation_config, history, return_history, num_patches_list, IMG_START_TOKEN, IMG_END_TOKEN, IMG_CONTEXT_TOKEN, verbose)
#     288 attention_mask = model_inputs['attention_mask'].to(self.device)
#     289 generation_config['eos_token_id'] = eos_token_id
# --> 290 generation_output = self.generate(
#     291     pixel_values=pixel_values,
#     292     input_ids=input_ids,
#     293     attention_mask=attention_mask,
#     294     **generation_config
#     295 )
#     296 response = tokenizer.batch_decode(generation_output, skip_special_tokens=True)[0]
#     297 response = response.split(template.sep)[0].strip()
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internvl_chat.py:340, in InternVLChatModel.generate(self, pixel_values, input_ids, attention_mask, visual_features, generation_config, output_hidden_states, return_dict, **generate_kwargs)
#     337 else:
#     338     input_embeds = self.language_model.get_input_embeddings()(input_ids)
# --> 340 outputs = self.language_model.generate(
#     341     inputs_embeds=input_embeds,
#     342     attention_mask=attention_mask,
#     343     generation_config=generation_config,
#     344     output_hidden_states=output_hidden_states,
#     345     return_dict=return_dict,
#     346     use_cache=True,
#     347     **generate_kwargs,
#     348 )
#     350 return outputs
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/generation/utils.py:2047, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2039     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2040         input_ids=input_ids,
#    2041         expand_size=generation_config.num_return_sequences,
#    2042         is_encoder_decoder=self.config.is_encoder_decoder,
#    2043         **model_kwargs,
#    2044     )
#    2046     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2047     result = self._sample(
#    2048         input_ids,
#    2049         logits_processor=prepared_logits_processor,
#    2050         stopping_criteria=prepared_stopping_criteria,
#    2051         generation_config=generation_config,
#    2052         synced_gpus=synced_gpus,
#    2053         streamer=streamer,
#    2054         **model_kwargs,
#    2055     )
#    2057 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2058     # 11. prepare beam search scorer
#    2059     beam_scorer = BeamSearchScorer(
#    2060         batch_size=batch_size,
#    2061         num_beams=generation_config.num_beams,
#    (...)
#    2066         max_length=generation_config.max_length,
#    2067     )
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/generation/utils.py:3007, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3004 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3006 # forward pass to get next token
# -> 3007 outputs = self(**model_inputs, return_dict=True)
#    3009 if synced_gpus and this_peer_finished:
#    3010     continue  # don't waste resources running the code we don't need
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internlm2.py:1068, in InternLM2ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1065 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1067 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1068 outputs = self.model(
#    1069     input_ids=input_ids,
#    1070     attention_mask=attention_mask,
#    1071     position_ids=position_ids,
#    1072     past_key_values=past_key_values,
#    1073     inputs_embeds=inputs_embeds,
#    1074     use_cache=use_cache,
#    1075     output_attentions=output_attentions,
#    1076     output_hidden_states=output_hidden_states,
#    1077     return_dict=return_dict,
#    1078 )
#    1080 hidden_states = outputs[0]
#    1081 logits = self.output(hidden_states)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internlm2.py:953, in InternLM2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     945     layer_outputs = torch.utils.checkpoint.checkpoint(
#     946         create_custom_forward(decoder_layer),
#     947         hidden_states,
#    (...)
#     950         None,
#     951     )
#     952 else:
# --> 953     layer_outputs = decoder_layer(
#     954         hidden_states,
#     955         attention_mask=attention_mask,
#     956         position_ids=position_ids,
#     957         past_key_value=past_key_value,
#     958         output_attentions=output_attentions,
#     959         use_cache=use_cache,
#     960     )
#     962 hidden_states = layer_outputs[0]
#     964 if use_cache:
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internlm2.py:656, in InternLM2DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     653 hidden_states = self.attention_norm(hidden_states)
#     655 # Self Attention
# --> 656 hidden_states, self_attn_weights, present_key_value = self.attention(
#     657     hidden_states=hidden_states,
#     658     attention_mask=attention_mask,
#     659     position_ids=position_ids,
#     660     past_key_value=past_key_value,
#     661     output_attentions=output_attentions,
#     662     use_cache=use_cache,
#     663     **kwargs,
#     664 )
#     665 hidden_states = residual + hidden_states
#     667 # Fully Connected
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/OpenGVLab/InternVL2-8B/c527cd3717f4bb8339002b342bc9476ec0485004/modeling_internlm2.py:393, in InternLM2Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     390 key_states = repeat_kv(key_states, self.num_key_value_groups)
#     391 value_states = repeat_kv(value_states, self.num_key_value_groups)
# --> 393 attn_weights = torch.matmul(query_states, key_states.transpose(2, 3)) / math.sqrt(self.head_dim)
#     395 if attn_weights.size() != (bsz, self.num_heads, q_len, kv_seq_len):
#     396     raise ValueError(
#     397         f'Attention weights should be of size {(bsz, self.num_heads, q_len, kv_seq_len)}, but is'
#     398         f' {attn_weights.size()}'
#     399     )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 7.99 GiB. GPU 0 has a total capacity of 21.99 GiB of which 3.65 GiB is free. Including non-PyTorch memory, this process has 18.33 GiB memory in use. Of the allocated memory 16.59 GiB is allocated by PyTorch, and 1.43 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
len(captions_fps)
# Out:
# ['This image shows a busy urban street scene. Multiple lanes are visible, filled with cars, motorcycles, and other forms of public transportation such as buses and trucks. There is a mix of older and newer vehicles, with a significant number of commercial vehicles including trucks and buses. Pedestrians can be seen crossing the streets or walking along the sidewalks. The image includes overhead markings, road signs, and traffic lights. The street is flanked by buildings and there is greenery around the area. The date and time stamp at the top of the image indicate it was taken on Tuesday, December 12, 2023, at 15:45:49.',
#  'The image depicts a street scene in a city, captured by a security camera. The timestamp indicates the date as December 12, 2023, at 3:47 PM. The location is Krishna Kanthi Nethaji Bridge, according to the text in the image. \n\nThe road is divided into several lanes for vehicular traffic. On the left side of the image, there is a sidewalk with pedestrians walking. The sidewalk appears crowded, with people possibly waiting at a bus stop or a crossing point. Several motorcycles and cars are also visible, creating a bustling atmosphere.\n\nOn the right side of the image, traffic flows in two directions. The rightmost lane is occupied by a yellow public transport bus heading towards the top of the image. A white truck is also visible, transporting goods. In the background, additional public transport vehicles, cars, and motorcycles fill the scene, indicating dense traffic typical of a busy city.\n\nThere are pedestrians on the left sidewalk, and the greenery and urban infrastructure are in sight. Buildings, utility poles, and street vendors add to the urban fabric.',
#  'The image shows a busy urban street scene captured on December 12, 2023, at 3:47 PM during the afternoon hours, as indicated by the timestamp. The street, named Krishnabai Kamal Wari Bridge, is bustling with a variety of vehicles and motorcycles, with a mix of cars, trucks, motorbikes, and buses visible. On the roads, several trucks carrying cargo are prominent, alongside cars and buses. There are people walking and waiting by the roadside, and the area appears to be part of a commercial street with shops and businesses visible in the background. Signs and billboards are also present, indicating a dynamic and active commercial district.',
#  'The image depicts a busy highway around Krishnapura Cantt, Krishnapura, on a weekday. Traffic is heavy, with numerous cars, motorcycles, bicycles, and buses visible. The time is 12:12 on Tuesday, and the date is December 12, 2023. There are construction barriers on the right side of the road, indicating ongoing work or maintenance. A variety of vehicles, including private cars, commercial trucks, and motorcycles, are navigating the dense traffic. Trees and some greenery are visible along the sides of the road, adding to the urban scenery.',
#  'The image portrays a busy street scene in what appears to be part of the city of Krishnapura, Kanksha Bridge, on November 12, 2023, at 15:40. The street is bustling with vehicles and people, suggesting a busy moment on an urban road. The major vehicles include trucks, cars, motorcycles, and auto-rickshaws. On the left side of the road, pedestrian activity is evident with people walking and cycling. A truck is being turned around, which is causing some congestion. Further down the road, a large truck and multiple other vehicles are visible, indicating possible significant local or regional highway traffic.']

# %%
# Importing the required libraries
import os
import openai
from langchain import OpenAI
from langchain.chains.summarize import load_summarize_chain
from langchain.prompts import PromptTemplate
from langchain.docstore.document import Document
from langchain.chat_models import ChatOpenAI

# Setting the OPEN AI API Key from Environment Variable
# Load GPT-3.5-turbo via LangChain
llm = ChatOpenAI(openai_api_key=openai.api_key, model_name="gpt-3.5-turbo", temperature=0.5)

# Function to summarize the text using GPT-3.5-turbo
class LangchainSummarizer:
    def summarize_with_langchain(self, list_text):
        text = " ".join(list_text)
        document = Document(page_content=text)
        chain = load_summarize_chain(llm, chain_type="map_reduce")
        summary = chain.run([document])
        return summary

# %%
class Video2Text():
    def __init__(self, video_path, output_folder, model_path='OpenGVLab/InternVL2-8B'):
        self.video_path = video_path
        self.output_folder = output_folder
        self.model_path = model_path
        self.video_processor = VideoProcessor(video_path, output_folder)
        self.image_processor = ImageProcessor(model_path)
        self.langchain_summarizer = LangchainSummarizer()
        self.reduce_redunant = ReduceRedunant()

    def process_video(self):
        frames_1sec = self.video_processor.process_video()
        print("Video to Frames conversion completed successfully")
        return frames_1sec
    
    def remove_redundant(self, images):
        reduced_images = self.reduce_redunant.reduce_images(images, 5)
        self.reduce_redunant.save_images(reduced_images, save_path='reduced_images', num_images=5)
        print("Redundant frames removed successfully")
        return reduced_images
    
    def captioning(self, images):
        paths_list=[]
        for img_path in os.listdir(images):
            paths_list.append(os.path.join(images, img_path))
        captions_fps = self.image_processor.frame_iter(paths_list)
        print("Captioned every 5 frames successfully")
        return captions_fps
    
    def summarize_text(self, captions):
        summaries_1sec = []
        for caption in captions:
            summary = self.langchain_summarizer.summarize_with_langchain(caption)
            summaries_1sec.append(summary)
        print("Text Summarized successfully")
        return summaries_1sec
    
    def forward(self):
        frames_1sec = self.process_video()
        reduced_images = self.remove_redundant(frames_1sec)
        captions_fps = self.captioning(reduced_images)
        summaries_1sec = self.summarize_text(captions_fps)
        return summaries_1sec

# %%
sums = Video2Text(video_path='src/vid1.mp4', output_folder="outputs")
